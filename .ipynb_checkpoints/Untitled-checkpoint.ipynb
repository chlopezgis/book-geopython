# %%
# !jupyter-book create geopython
# Out:
# ...
#
# Your book template can be found at
#
#     geopython\
#
# ...

# %%
# !jupyter-book build --all geopython/
# Out:
# Running Jupyter-Book v1.0.3
# Source Folder: D:\Charlie\04_Github\book-geopython\geopython
# Config Path: D:\Charlie\04_Github\book-geopython\geopython\_config.yml
# Output Path: D:\Charlie\04_Github\book-geopython\geopython\_build\html
# Running Sphinx v7.4.7
# loading translations [en]... done
# [etoc] Changing master_doc to 'intro'
# checking bibtex cache... out of date
# parsing bibtex file D:\Charlie\04_Github\book-geopython\geopython\references.bib... parsed 5 entries
# ...
